# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
coordinates = list(lat_lngs)

# %%
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Import the requests library.
import requests

# %%
# Import the API key.
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_desc = city_weather["weather"][0]["description"]

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": current_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | grand forks
# Processing Record 3 of Set 1 | svetlaya
# Processing Record 4 of Set 1 | basco
# Processing Record 5 of Set 1 | ribeira grande
# Processing Record 6 of Set 1 | paris
# Processing Record 7 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 1 | leningradskiy
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | kibala
# Processing Record 12 of Set 1 | butaritari
# Processing Record 13 of Set 1 | tari
# Processing Record 14 of Set 1 | lebu
# Processing Record 15 of Set 1 | chuy
# Processing Record 16 of Set 1 | kodiak
# Processing Record 17 of Set 1 | georgetown
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | dhidhdhoo
# Processing Record 20 of Set 1 | aranos
# Processing Record 21 of Set 1 | bengkulu
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | solnechnyy
# Processing Record 25 of Set 1 | bluff
# Processing Record 26 of Set 1 | grand-santi
# Processing Record 27 of Set 1 | portland
# Processing Record 28 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 1 | bestobe
# Processing Record 31 of Set 1 | nikolskoye
# Processing Record 32 of Set 1 | vagay
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | ancud
# Processing Record 36 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | luderitz
# Processing Record 39 of Set 1 | olafsvik
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | port keats
# Processing Record 42 of Set 1 | khani
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | ponta do sol
# Processing Record 45 of Set 1 | balkhash
# Processing Record 46 of Set 1 | tromso
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | watertown
# Processing Record 49 of Set 1 | cherskiy
# Processing Record 50 of Set 1 | visby
# Processing Record 1 of Set 2 | qaanaaq
# Processing Record 2 of Set 2 | ilulissat
# Processing Record 3 of Set 2 | new norfolk
# Processing Record 4 of Set 2 | torbay
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | pevek
# Processing Record 7 of Set 2 | yellowknife
# Processing Record 8 of Set 2 | arroyo
# Processing Record 9 of Set 2 | saint george
# Processing Record 10 of Set 2 | hilo
# Processing Record 11 of Set 2 | norman wells
# Processing Record 12 of Set 2 | airai
# Processing Record 13 of Set 2 | jinxiang
# Processing Record 14 of Set 2 | longavi
# Processing Record 15 of Set 2 | yunyang
# Processing Record 16 of Set 2 | shasta lake
# Processing Record 17 of Set 2 | lagoa
# Processing Record 18 of Set 2 | alice springs
# Processing Record 19 of Set 2 | zhangjiakou
# Processing Record 20 of Set 2 | tongchuan
# Processing Record 21 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 2 | gemena
# Processing Record 23 of Set 2 | cockburn town
# Processing Record 24 of Set 2 | aksu
# Processing Record 25 of Set 2 | ushuaia
# Processing Record 26 of Set 2 | mizpe ramon
# City not found. Skipping...
# Processing Record 27 of Set 2 | baykit
# Processing Record 28 of Set 2 | saint-philippe
# Processing Record 29 of Set 2 | ayagoz
# Processing Record 30 of Set 2 | rikitea
# Processing Record 31 of Set 2 | hirara
# Processing Record 32 of Set 2 | east london
# Processing Record 33 of Set 2 | brae
# Processing Record 34 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 35 of Set 2 | miles city
# Processing Record 36 of Set 2 | faanui
# Processing Record 37 of Set 2 | zhanakorgan
# Processing Record 38 of Set 2 | hermanus
# Processing Record 39 of Set 2 | manicore
# Processing Record 40 of Set 2 | vila franca do campo
# Processing Record 41 of Set 2 | maua
# Processing Record 42 of Set 2 | umm durman
# City not found. Skipping...
# Processing Record 43 of Set 2 | zyryanka
# Processing Record 44 of Set 2 | turnu magurele
# Processing Record 45 of Set 2 | beringovskiy
# Processing Record 46 of Set 2 | hobart
# Processing Record 47 of Set 2 | kavieng
# Processing Record 48 of Set 2 | najran
# Processing Record 49 of Set 2 | pisco
# Processing Record 50 of Set 2 | victoria
# Processing Record 1 of Set 3 | kaitangata
# Processing Record 2 of Set 3 | cao bang
# Processing Record 3 of Set 3 | khatanga
# Processing Record 4 of Set 3 | yulara
# Processing Record 5 of Set 3 | bambous virieux
# Processing Record 6 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 7 of Set 3 | barrow
# Processing Record 8 of Set 3 | nome
# Processing Record 9 of Set 3 | mar del plata
# Processing Record 10 of Set 3 | golyshmanovo
# Processing Record 11 of Set 3 | chuguyevka
# Processing Record 12 of Set 3 | koulamoutou
# Processing Record 13 of Set 3 | salalah
# Processing Record 14 of Set 3 | puerto del rosario
# Processing Record 15 of Set 3 | nantucket
# Processing Record 16 of Set 3 | tasiilaq
# Processing Record 17 of Set 3 | santa maria
# Processing Record 18 of Set 3 | borgarnes
# Processing Record 19 of Set 3 | rio gallegos
# Processing Record 20 of Set 3 | bac lieu
# Processing Record 21 of Set 3 | honningsvag
# Processing Record 22 of Set 3 | singkang
# Processing Record 23 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 3 | san policarpo
# Processing Record 25 of Set 3 | makakilo city
# Processing Record 26 of Set 3 | kavaratti
# Processing Record 27 of Set 3 | touros
# Processing Record 28 of Set 3 | nioki
# Processing Record 29 of Set 3 | vizinga
# Processing Record 30 of Set 3 | upernavik
# Processing Record 31 of Set 3 | miri
# Processing Record 32 of Set 3 | carnarvon
# Processing Record 33 of Set 3 | nacala
# Processing Record 34 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 35 of Set 3 | yomitan
# City not found. Skipping...
# Processing Record 36 of Set 3 | padang
# Processing Record 37 of Set 3 | tuatapere
# Processing Record 38 of Set 3 | iqaluit
# Processing Record 39 of Set 3 | wuning
# Processing Record 40 of Set 3 | kilindoni
# Processing Record 41 of Set 3 | odienne
# Processing Record 42 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 3 | adre
# Processing Record 44 of Set 3 | alofi
# Processing Record 45 of Set 3 | matara
# Processing Record 46 of Set 3 | moissala
# Processing Record 47 of Set 3 | tuktoyaktuk
# Processing Record 48 of Set 3 | pochutla
# Processing Record 49 of Set 3 | pangnirtung
# Processing Record 50 of Set 3 | cidreira
# Processing Record 1 of Set 4 | alakurtti
# Processing Record 2 of Set 4 | udomlya
# Processing Record 3 of Set 4 | lafia
# Processing Record 4 of Set 4 | longyearbyen
# Processing Record 5 of Set 4 | manta
# Processing Record 6 of Set 4 | jiaonan
# Processing Record 7 of Set 4 | kotovo
# Processing Record 8 of Set 4 | coolum beach
# Processing Record 9 of Set 4 | naron
# Processing Record 10 of Set 4 | arraial do cabo
# Processing Record 11 of Set 4 | bredasdorp
# Processing Record 12 of Set 4 | puerto ayora
# Processing Record 13 of Set 4 | eureka
# Processing Record 14 of Set 4 | fomboni
# Processing Record 15 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 4 | pandan
# Processing Record 17 of Set 4 | sur
# Processing Record 18 of Set 4 | aksha
# Processing Record 19 of Set 4 | okha
# Processing Record 20 of Set 4 | sao joao da barra
# Processing Record 21 of Set 4 | makung
# City not found. Skipping...
# Processing Record 22 of Set 4 | kaputa
# Processing Record 23 of Set 4 | la libertad
# Processing Record 24 of Set 4 | pinczow
# Processing Record 25 of Set 4 | labuhan
# Processing Record 26 of Set 4 | klaksvik
# Processing Record 27 of Set 4 | minab
# Processing Record 28 of Set 4 | ketchikan
# Processing Record 29 of Set 4 | kondinskoye
# Processing Record 30 of Set 4 | hofn
# Processing Record 31 of Set 4 | loralai
# Processing Record 32 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 4 | guerrero negro
# Processing Record 34 of Set 4 | cabo san lucas
# Processing Record 35 of Set 4 | shagonar
# Processing Record 36 of Set 4 | pangai
# Processing Record 37 of Set 4 | shimoda
# Processing Record 38 of Set 4 | erenhot
# Processing Record 39 of Set 4 | puerto escondido
# Processing Record 40 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 4 | calafell
# Processing Record 42 of Set 4 | aquiles serdan
# Processing Record 43 of Set 4 | kieta
# Processing Record 44 of Set 4 | kabo
# Processing Record 45 of Set 4 | maceio
# Processing Record 46 of Set 4 | severo-kurilsk
# Processing Record 47 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 4 | wasilla
# Processing Record 49 of Set 4 | taltal
# Processing Record 50 of Set 4 | henties bay
# Processing Record 1 of Set 5 | laguna
# Processing Record 2 of Set 5 | villa bisono
# Processing Record 3 of Set 5 | ormara
# Processing Record 4 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 5 | calatayud
# Processing Record 6 of Set 5 | tanout
# Processing Record 7 of Set 5 | dikson
# Processing Record 8 of Set 5 | husavik
# Processing Record 9 of Set 5 | dingle
# Processing Record 10 of Set 5 | vardo
# Processing Record 11 of Set 5 | ahipara
# Processing Record 12 of Set 5 | deh rawud
# City not found. Skipping...
# Processing Record 13 of Set 5 | saskylakh
# Processing Record 14 of Set 5 | eyl
# Processing Record 15 of Set 5 | natal
# Processing Record 16 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 5 | souillac
# Processing Record 18 of Set 5 | znamenskoye
# Processing Record 19 of Set 5 | muskegon
# Processing Record 20 of Set 5 | oranjestad
# Processing Record 21 of Set 5 | moyale
# Processing Record 22 of Set 5 | weyburn
# Processing Record 23 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 24 of Set 5 | jutai
# Processing Record 25 of Set 5 | otane
# Processing Record 26 of Set 5 | passo de camaragibe
# Processing Record 27 of Set 5 | peniche
# Processing Record 28 of Set 5 | hami
# Processing Record 29 of Set 5 | springdale
# Processing Record 30 of Set 5 | burrel
# Processing Record 31 of Set 5 | weligama
# Processing Record 32 of Set 5 | sandpoint
# Processing Record 33 of Set 5 | codrington
# Processing Record 34 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 35 of Set 5 | rio claro
# Processing Record 36 of Set 5 | saryozek
# Processing Record 37 of Set 5 | mahajanga
# Processing Record 38 of Set 5 | kutum
# Processing Record 39 of Set 5 | yarensk
# Processing Record 40 of Set 5 | lazarev
# Processing Record 41 of Set 5 | yatou
# Processing Record 42 of Set 5 | leh
# Processing Record 43 of Set 5 | muros
# Processing Record 44 of Set 5 | wum
# Processing Record 45 of Set 5 | encruzilhada do sul
# Processing Record 46 of Set 5 | hervey bay
# Processing Record 47 of Set 5 | saint-francois
# Processing Record 48 of Set 5 | batemans bay
# Processing Record 49 of Set 5 | upata
# Processing Record 50 of Set 5 | kassala
# Processing Record 1 of Set 6 | takhli
# Processing Record 2 of Set 6 | port-de-paix
# City not found. Skipping...
# Processing Record 3 of Set 6 | srednekolymsk
# Processing Record 4 of Set 6 | skjervoy
# Processing Record 5 of Set 6 | gat
# Processing Record 6 of Set 6 | adrar
# Processing Record 7 of Set 6 | kahului
# Processing Record 8 of Set 6 | sorland
# Processing Record 9 of Set 6 | namibe
# Processing Record 10 of Set 6 | marsa matruh
# Processing Record 11 of Set 6 | gladstone
# Processing Record 12 of Set 6 | olinda
# Processing Record 13 of Set 6 | salinas
# Processing Record 14 of Set 6 | doha
# Processing Record 15 of Set 6 | frogner
# Processing Record 16 of Set 6 | esso
# Processing Record 17 of Set 6 | lugovskiy
# City not found. Skipping...
# Processing Record 18 of Set 6 | bokoro
# Processing Record 19 of Set 6 | ostrovnoy
# Processing Record 20 of Set 6 | ziro
# Processing Record 21 of Set 6 | marzuq
# Processing Record 22 of Set 6 | port-gentil
# Processing Record 23 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 6 | phuntsholing
# Processing Record 25 of Set 6 | limin khersonisou
# Processing Record 26 of Set 6 | leshukonskoye
# Processing Record 27 of Set 6 | te anau
# Processing Record 28 of Set 6 | san patricio
# Processing Record 29 of Set 6 | loandjili
# Processing Record 30 of Set 6 | bijeljina
# Processing Record 31 of Set 6 | montepuez
# Processing Record 32 of Set 6 | grindavik
# Processing Record 33 of Set 6 | gannan
# Processing Record 34 of Set 6 | nabire
# Processing Record 35 of Set 6 | hithadhoo
# Processing Record 36 of Set 6 | araouane
# Processing Record 37 of Set 6 | kruisfontein
# Processing Record 38 of Set 6 | ulladulla
# Processing Record 39 of Set 6 | busing
# Processing Record 40 of Set 6 | mamontovo
# Processing Record 41 of Set 6 | mahebourg
# Processing Record 42 of Set 6 | narsaq
# Processing Record 43 of Set 6 | pali
# Processing Record 44 of Set 6 | idritsa
# Processing Record 45 of Set 6 | menongue
# Processing Record 46 of Set 6 | nakambala
# Processing Record 47 of Set 6 | copacabana
# Processing Record 48 of Set 6 | parana
# Processing Record 49 of Set 6 | begoro
# Processing Record 50 of Set 6 | blagoveshchenka
# Processing Record 1 of Set 7 | jacksonville
# Processing Record 2 of Set 7 | ngunguru
# Processing Record 3 of Set 7 | constitucion
# Processing Record 4 of Set 7 | tiksi
# Processing Record 5 of Set 7 | seoul
# Processing Record 6 of Set 7 | sao filipe
# Processing Record 7 of Set 7 | camacha
# Processing Record 8 of Set 7 | sangerhausen
# Processing Record 9 of Set 7 | hasaki
# Processing Record 10 of Set 7 | toowoomba
# Processing Record 11 of Set 7 | kawalu
# Processing Record 12 of Set 7 | castro
# Processing Record 13 of Set 7 | manaus
# Processing Record 14 of Set 7 | korla
# Processing Record 15 of Set 7 | anloga
# Processing Record 16 of Set 7 | chapais
# Processing Record 17 of Set 7 | royan
# Processing Record 18 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 19 of Set 7 | thompson
# Processing Record 20 of Set 7 | naze
# Processing Record 21 of Set 7 | olenegorsk
# Processing Record 22 of Set 7 | inta
# Processing Record 23 of Set 7 | havelock
# Processing Record 24 of Set 7 | pizhanka
# Processing Record 25 of Set 7 | batagay-alyta
# Processing Record 26 of Set 7 | kirkwall
# Processing Record 27 of Set 7 | port elizabeth
# Processing Record 28 of Set 7 | pokaran
# Processing Record 29 of Set 7 | curaca
# Processing Record 30 of Set 7 | faya
# Processing Record 31 of Set 7 | siderno
# Processing Record 32 of Set 7 | atambua
# Processing Record 33 of Set 7 | dekar
# Processing Record 34 of Set 7 | bukama
# Processing Record 35 of Set 7 | mhlambanyatsi
# Processing Record 36 of Set 7 | springfield
# Processing Record 37 of Set 7 | acapulco
# Processing Record 38 of Set 7 | tahlequah
# Processing Record 39 of Set 7 | milyutinskaya
# Processing Record 40 of Set 7 | nadym
# Processing Record 41 of Set 7 | hovd
# Processing Record 42 of Set 7 | burayevo
# Processing Record 43 of Set 7 | manaure
# Processing Record 44 of Set 7 | provideniya
# Processing Record 45 of Set 7 | bireun
# Processing Record 46 of Set 7 | opunake
# Processing Record 47 of Set 7 | igrim
# Processing Record 48 of Set 7 | vostok
# Processing Record 49 of Set 7 | gloversville
# Processing Record 50 of Set 7 | bonavista
# Processing Record 1 of Set 8 | hamilton
# Processing Record 2 of Set 8 | byron bay
# Processing Record 3 of Set 8 | sawtell
# Processing Record 4 of Set 8 | diffa
# Processing Record 5 of Set 8 | cabedelo
# Processing Record 6 of Set 8 | flinders
# Processing Record 7 of Set 8 | vila velha
# Processing Record 8 of Set 8 | dandong
# Processing Record 9 of Set 8 | armacao dos buzios
# City not found. Skipping...
# Processing Record 10 of Set 8 | galgani
# City not found. Skipping...
# Processing Record 11 of Set 8 | nouadhibou
# Processing Record 12 of Set 8 | bethel
# Processing Record 13 of Set 8 | koungou
# Processing Record 14 of Set 8 | prince rupert
# Processing Record 15 of Set 8 | mount isa
# Processing Record 16 of Set 8 | taylorville
# Processing Record 17 of Set 8 | gold coast
# Processing Record 18 of Set 8 | rakhya
# City not found. Skipping...
# Processing Record 19 of Set 8 | gorin
# Processing Record 20 of Set 8 | monywa
# Processing Record 21 of Set 8 | jining
# Processing Record 22 of Set 8 | fortuna
# Processing Record 23 of Set 8 | laramie
# Processing Record 24 of Set 8 | mountain home
# Processing Record 25 of Set 8 | manavalakurichi
# Processing Record 26 of Set 8 | spanish town
# Processing Record 27 of Set 8 | batsfjord
# Processing Record 28 of Set 8 | nhulunbuy
# Processing Record 29 of Set 8 | saint-ambroise
# Processing Record 30 of Set 8 | mount gambier
# Processing Record 31 of Set 8 | lata
# Processing Record 32 of Set 8 | zuwarah
# Processing Record 33 of Set 8 | rodrigues alves
# Processing Record 34 of Set 8 | almeirim
# Processing Record 35 of Set 8 | port lincoln
# Processing Record 36 of Set 8 | atyrau
# Processing Record 37 of Set 8 | balkanabat
# Processing Record 38 of Set 8 | colquechaca
# Processing Record 39 of Set 8 | panara
# Processing Record 40 of Set 8 | teacapan
# Processing Record 41 of Set 8 | mto wa mbu
# Processing Record 42 of Set 8 | nuevo laredo
# Processing Record 43 of Set 8 | chumikan
# Processing Record 44 of Set 8 | gilbues
# Processing Record 45 of Set 8 | jennings
# Processing Record 46 of Set 8 | nanortalik
# Processing Record 47 of Set 8 | mulanje
# Processing Record 48 of Set 8 | ercis
# Processing Record 49 of Set 8 | port blair
# Processing Record 50 of Set 8 | geraldton
# Processing Record 1 of Set 9 | san mateo ixtatan
# Processing Record 2 of Set 9 | bosaso
# Processing Record 3 of Set 9 | cienfuegos
# Processing Record 4 of Set 9 | ucluelet
# Processing Record 5 of Set 9 | caetes
# Processing Record 6 of Set 9 | cabra
# Processing Record 7 of Set 9 | biloela
# Processing Record 8 of Set 9 | noumea
# Processing Record 9 of Set 9 | barabinsk
# Processing Record 10 of Set 9 | nova odesa
# Processing Record 11 of Set 9 | shenkursk
# Processing Record 12 of Set 9 | sitka
# Processing Record 13 of Set 9 | ayan
# Processing Record 14 of Set 9 | quepos
# Processing Record 15 of Set 9 | zeya
# Processing Record 16 of Set 9 | ayorou
# Processing Record 17 of Set 9 | esperance
# Processing Record 18 of Set 9 | constantine
# Processing Record 19 of Set 9 | dunedin
# Processing Record 20 of Set 9 | burnie
# Processing Record 21 of Set 9 | veraval
# Processing Record 22 of Set 9 | jaque
# Processing Record 23 of Set 9 | mecca
# Processing Record 24 of Set 9 | tayoltita
# Processing Record 25 of Set 9 | vao
# Processing Record 26 of Set 9 | yenagoa
# Processing Record 27 of Set 9 | tignere
# Processing Record 28 of Set 9 | auki
# Processing Record 29 of Set 9 | maposeni
# Processing Record 30 of Set 9 | emirdag
# Processing Record 31 of Set 9 | winneba
# Processing Record 32 of Set 9 | xinzhi
# Processing Record 33 of Set 9 | rocha
# Processing Record 34 of Set 9 | starkville
# Processing Record 35 of Set 9 | lazaro cardenas
# Processing Record 36 of Set 9 | shawnee
# Processing Record 37 of Set 9 | buala
# Processing Record 38 of Set 9 | ajdabiya
# Processing Record 39 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 9 | juniyah
# City not found. Skipping...
# Processing Record 41 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 42 of Set 9 | marawi
# Processing Record 43 of Set 9 | saint-louis
# Processing Record 44 of Set 9 | ahuimanu
# Processing Record 45 of Set 9 | puerto quijarro
# Processing Record 46 of Set 9 | waipawa
# Processing Record 47 of Set 9 | port hedland
# Processing Record 48 of Set 9 | namatanai
# Processing Record 49 of Set 9 | deputatskiy
# Processing Record 50 of Set 9 | gunjur
# Processing Record 1 of Set 10 | ahraura
# Processing Record 2 of Set 10 | mercedes
# Processing Record 3 of Set 10 | mareeba
# Processing Record 4 of Set 10 | ecija
# Processing Record 5 of Set 10 | half moon bay
# Processing Record 6 of Set 10 | susangerd
# Processing Record 7 of Set 10 | beloha
# Processing Record 8 of Set 10 | progreso
# Processing Record 9 of Set 10 | newport
# Processing Record 10 of Set 10 | maniitsoq
# Processing Record 11 of Set 10 | kiunga
# Processing Record 12 of Set 10 | lithgow
# Processing Record 13 of Set 10 | icanti
# City not found. Skipping...
# Processing Record 14 of Set 10 | sri aman
# Processing Record 15 of Set 10 | sumbe
# Processing Record 16 of Set 10 | whithorn
# Processing Record 17 of Set 10 | college
# Processing Record 18 of Set 10 | caravelas
# Processing Record 19 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 10 | katha
# City not found. Skipping...
# Processing Record 21 of Set 10 | puerto ayacucho
# Processing Record 22 of Set 10 | isangel
# Processing Record 23 of Set 10 | sao raimundo nonato
# Processing Record 24 of Set 10 | clarence town
# Processing Record 25 of Set 10 | derzhavinsk
# Processing Record 26 of Set 10 | burica
# City not found. Skipping...
# Processing Record 27 of Set 10 | mathathane
# Processing Record 28 of Set 10 | haines junction
# Processing Record 29 of Set 10 | qaqortoq
# Processing Record 30 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 31 of Set 10 | talnakh
# Processing Record 32 of Set 10 | pimentel
# Processing Record 33 of Set 10 | oulainen
# Processing Record 34 of Set 10 | coahuayana
# Processing Record 35 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 36 of Set 10 | lavrentiya
# Processing Record 37 of Set 10 | hals
# Processing Record 38 of Set 10 | kamina
# Processing Record 39 of Set 10 | greensboro
# Processing Record 40 of Set 10 | aykhal
# Processing Record 41 of Set 10 | bonga
# Processing Record 42 of Set 10 | tambul
# City not found. Skipping...
# Processing Record 43 of Set 10 | chokurdakh
# Processing Record 44 of Set 10 | ternate
# Processing Record 45 of Set 10 | ca mau
# Processing Record 46 of Set 10 | lasa
# Processing Record 47 of Set 10 | hazorasp
# Processing Record 48 of Set 10 | mazatlan
# Processing Record 49 of Set 10 | coruripe
# Processing Record 50 of Set 10 | bathsheba
# Processing Record 1 of Set 11 | thinadhoo
# Processing Record 2 of Set 11 | vila
# Processing Record 3 of Set 11 | sakakah
# Processing Record 4 of Set 11 | igarka
# Processing Record 5 of Set 11 | humboldt
# Processing Record 6 of Set 11 | talaya
# Processing Record 7 of Set 11 | toppenish
# Processing Record 8 of Set 11 | barra do garcas
# Processing Record 9 of Set 11 | santa cruz
# Processing Record 10 of Set 11 | samarai
# Processing Record 11 of Set 11 | malgrat de mar
# Processing Record 12 of Set 11 | contai
# Processing Record 13 of Set 11 | vangaindrano
# Processing Record 14 of Set 11 | kharela
# Processing Record 15 of Set 11 | umea
# Processing Record 16 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 17 of Set 11 | gizo
# Processing Record 18 of Set 11 | fandriana
# Processing Record 19 of Set 11 | nushki
# Processing Record 20 of Set 11 | manoel urbano
# Processing Record 21 of Set 11 | pacific grove
# Processing Record 22 of Set 11 | soyo
# Processing Record 23 of Set 11 | camalu
# Processing Record 24 of Set 11 | port hardy
# Processing Record 25 of Set 11 | puri
# Processing Record 26 of Set 11 | eyemouth
# Processing Record 27 of Set 11 | papetoai
# Processing Record 28 of Set 11 | hambantota
# Processing Record 29 of Set 11 | kerteh
# City not found. Skipping...
# Processing Record 30 of Set 11 | luang prabang
# Processing Record 31 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 32 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 11 | lamar
# Processing Record 34 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 35 of Set 11 | tigil
# Processing Record 36 of Set 11 | namwala
# Processing Record 37 of Set 11 | flin flon
# Processing Record 38 of Set 11 | wagar
# Processing Record 39 of Set 11 | diego de almagro
# Processing Record 40 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 11 | barreiras
# Processing Record 42 of Set 11 | khammam
# Processing Record 43 of Set 11 | santa fe
# Processing Record 44 of Set 11 | naantali
# Processing Record 45 of Set 11 | qandala
# Processing Record 46 of Set 11 | tungkang
# City not found. Skipping...
# Processing Record 47 of Set 11 | shihezi
# Processing Record 48 of Set 11 | fare
# Processing Record 49 of Set 11 | los llanos de aridane
# Processing Record 50 of Set 11 | payakumbuh
# Processing Record 1 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 12 | regina
# Processing Record 3 of Set 12 | mineral wells
# Processing Record 4 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 12 | mandera
# Processing Record 6 of Set 12 | ostersund
# Processing Record 7 of Set 12 | kumeny
# Processing Record 8 of Set 12 | uzunovo
# Processing Record 9 of Set 12 | north platte
# Processing Record 10 of Set 12 | saldanha
# Processing Record 11 of Set 12 | waddan
# Processing Record 12 of Set 12 | dakar
# Processing Record 13 of Set 12 | snyder
# Processing Record 14 of Set 12 | anjozorobe
# Processing Record 15 of Set 12 | merauke
# Processing Record 16 of Set 12 | vanderhoof
# Processing Record 17 of Set 12 | cayenne
# Processing Record 18 of Set 12 | foz
# Processing Record 19 of Set 12 | alyangula
# Processing Record 20 of Set 12 | katsuura
# Processing Record 21 of Set 12 | san jeronimo
# Processing Record 22 of Set 12 | homer
# Processing Record 23 of Set 12 | porosozero
# Processing Record 24 of Set 12 | chontalpa
# Processing Record 25 of Set 12 | perpignan
# Processing Record 26 of Set 12 | kazincbarcika
# Processing Record 27 of Set 12 | sola
# Processing Record 28 of Set 12 | kitimat
# Processing Record 29 of Set 12 | ohringen
# Processing Record 30 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 31 of Set 12 | poum
# Processing Record 32 of Set 12 | mindif
# Processing Record 33 of Set 12 | karlskoga
# Processing Record 34 of Set 12 | tutayev
# Processing Record 35 of Set 12 | san quintin
# Processing Record 36 of Set 12 | wanning
# Processing Record 37 of Set 12 | piracicaba
# Processing Record 38 of Set 12 | aldan
# Processing Record 39 of Set 12 | tapaua
# City not found. Skipping...
# Processing Record 40 of Set 12 | erdenet
# Processing Record 41 of Set 12 | aksarka
# Processing Record 42 of Set 12 | terrenate
# Processing Record 43 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 12 | palasa
# Processing Record 45 of Set 12 | imeni babushkina
# Processing Record 46 of Set 12 | arman
# Processing Record 47 of Set 12 | comodoro rivadavia
# Processing Record 48 of Set 12 | pundaguitan
# Processing Record 49 of Set 12 | kirakira
# Processing Record 50 of Set 12 | tocopilla
# Processing Record 1 of Set 13 | olga
# Processing Record 2 of Set 13 | altay
# Processing Record 3 of Set 13 | orumiyeh
# Processing Record 4 of Set 13 | baker city
# Processing Record 5 of Set 13 | knyaze-volkonskoye
# Processing Record 6 of Set 13 | alihe
# Processing Record 7 of Set 13 | macamic
# Processing Record 8 of Set 13 | tortoli
# Processing Record 9 of Set 13 | gushikawa
# Processing Record 10 of Set 13 | kleck
# City not found. Skipping...
# Processing Record 11 of Set 13 | nemuro
# Processing Record 12 of Set 13 | agadez
# Processing Record 13 of Set 13 | oistins
# Processing Record 14 of Set 13 | khorol
# Processing Record 15 of Set 13 | beihai
# Processing Record 16 of Set 13 | presidencia roque saenz pena
# Processing Record 17 of Set 13 | saint-gilles
# Processing Record 18 of Set 13 | ust-nera
# Processing Record 19 of Set 13 | tyrma
# Processing Record 20 of Set 13 | hulan
# Processing Record 21 of Set 13 | vanimo
# Processing Record 22 of Set 13 | asau
# Processing Record 23 of Set 13 | alta floresta
# Processing Record 24 of Set 13 | birjand
# Processing Record 25 of Set 13 | mariel
# Processing Record 26 of Set 13 | marsh harbour
# Processing Record 27 of Set 13 | korem
# Processing Record 28 of Set 13 | barentu
# Processing Record 29 of Set 13 | moindou
# Processing Record 30 of Set 13 | khartoum
# Processing Record 31 of Set 13 | ovalle
# Processing Record 32 of Set 13 | okhotsk
# Processing Record 33 of Set 13 | carutapera
# Processing Record 34 of Set 13 | turukhansk
# Processing Record 35 of Set 13 | saint-prosper
# Processing Record 36 of Set 13 | tamiahua
# Processing Record 37 of Set 13 | kelvington
# Processing Record 38 of Set 13 | koboldo
# City not found. Skipping...
# Processing Record 39 of Set 13 | dobrinka
# Processing Record 40 of Set 13 | lorengau
# Processing Record 41 of Set 13 | kodinsk
# Processing Record 42 of Set 13 | biu
# Processing Record 43 of Set 13 | cocoyoc
# Processing Record 44 of Set 13 | omsukchan
# Processing Record 45 of Set 13 | channel-port aux basques
# Processing Record 46 of Set 13 | uvinza
# Processing Record 47 of Set 13 | aklavik
# Processing Record 48 of Set 13 | skage
# City not found. Skipping...
# Processing Record 49 of Set 13 | karibib
# Processing Record 50 of Set 13 | avera
# Processing Record 1 of Set 14 | mujiayingzi
# Processing Record 2 of Set 14 | tonj
# Processing Record 3 of Set 14 | bilibino
# Processing Record 4 of Set 14 | xinzhou
# Processing Record 5 of Set 14 | coquimbo
# Processing Record 6 of Set 14 | port augusta
# Processing Record 7 of Set 14 | hit
# Processing Record 8 of Set 14 | kitgum
# Processing Record 9 of Set 14 | deqing
# Processing Record 10 of Set 14 | rosetta
# Processing Record 11 of Set 14 | usolye
# Processing Record 12 of Set 14 | nador
# Processing Record 13 of Set 14 | leeds
# Processing Record 14 of Set 14 | wageningen
# Processing Record 15 of Set 14 | ossora
# Processing Record 16 of Set 14 | sangar
# Processing Record 17 of Set 14 | atar
# Processing Record 18 of Set 14 | limbourg
# Processing Record 19 of Set 14 | vanavara
# Processing Record 20 of Set 14 | dzilam gonzalez
# Processing Record 21 of Set 14 | jasper
# Processing Record 22 of Set 14 | totoral
# Processing Record 23 of Set 14 | aljezur
# Processing Record 24 of Set 14 | fuerte olimpo
# Processing Record 25 of Set 14 | rio grande
# Processing Record 26 of Set 14 | kenai
# Processing Record 27 of Set 14 | sao miguel do araguaia
# Processing Record 28 of Set 14 | meulaboh
# Processing Record 29 of Set 14 | sorong
# Processing Record 30 of Set 14 | moyo
# Processing Record 31 of Set 14 | santa ana
# Processing Record 32 of Set 14 | stokmarknes
# Processing Record 33 of Set 14 | san carlos de bariloche
# Processing Record 34 of Set 14 | chivay
# Processing Record 35 of Set 14 | launceston
# Processing Record 36 of Set 14 | kopavogur
# Processing Record 37 of Set 14 | tulun
# Processing Record 38 of Set 14 | hare bay
# Processing Record 39 of Set 14 | niono
# Processing Record 40 of Set 14 | bonthe
# Processing Record 41 of Set 14 | riyadh
# Processing Record 42 of Set 14 | rochegda
# Processing Record 43 of Set 14 | broome
# Processing Record 44 of Set 14 | honiara
# Processing Record 45 of Set 14 | kinsale
# Processing Record 46 of Set 14 | yaan
# Processing Record 47 of Set 14 | melfi
# Processing Record 48 of Set 14 | mandalgovi
# Processing Record 49 of Set 14 | pringsewu
# Processing Record 50 of Set 14 | emerald
# Processing Record 1 of Set 15 | ewa beach
# Processing Record 2 of Set 15 | scarborough
# Processing Record 3 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 4 of Set 15 | betong
# Processing Record 5 of Set 15 | chara
# Processing Record 6 of Set 15 | manger
# Processing Record 7 of Set 15 | tahoua
# Processing Record 8 of Set 15 | porto santo
# Processing Record 9 of Set 15 | abrau-dyurso
# Processing Record 10 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 11 of Set 15 | san jose de guanipa
# Processing Record 12 of Set 15 | mehamn
# Processing Record 13 of Set 15 | sosnovskoye
# Processing Record 14 of Set 15 | shingu
# Processing Record 15 of Set 15 | arzachena
# Processing Record 16 of Set 15 | chernyshevskiy
# Processing Record 17 of Set 15 | felanitx
# Processing Record 18 of Set 15 | moranbah
# Processing Record 19 of Set 15 | obo
# Processing Record 20 of Set 15 | anito
# Processing Record 21 of Set 15 | champerico
# Processing Record 22 of Set 15 | zolotyy potik
# Processing Record 23 of Set 15 | bako
# Processing Record 24 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 25 of Set 15 | sulangan
# Processing Record 26 of Set 15 | darhan
# Processing Record 27 of Set 15 | almaznyy
# Processing Record 28 of Set 15 | tondano
# Processing Record 29 of Set 15 | mamit
# Processing Record 30 of Set 15 | tautira
# Processing Record 31 of Set 15 | port macquarie
# Processing Record 32 of Set 15 | bull savanna
# Processing Record 33 of Set 15 | camopi
# Processing Record 34 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 35 of Set 15 | nosy varika
# Processing Record 36 of Set 15 | monte carmelo
# Processing Record 37 of Set 15 | taoudenni
# Processing Record 38 of Set 15 | samur
# Processing Record 39 of Set 15 | toktogul
# Processing Record 40 of Set 15 | abonnema
# Processing Record 41 of Set 15 | saint-leu
# Processing Record 42 of Set 15 | dzhebariki-khaya
# Processing Record 43 of Set 15 | uwayl
# City not found. Skipping...
# Processing Record 44 of Set 15 | sembe
# Processing Record 45 of Set 15 | vilhena
# Processing Record 46 of Set 15 | mantua
# Processing Record 47 of Set 15 | fougeres
# Processing Record 48 of Set 15 | yumen
# Processing Record 49 of Set 15 | hengyang
# Processing Record 50 of Set 15 | ruteng
# Processing Record 1 of Set 16 | luancheng
# Processing Record 2 of Set 16 | margate
# Processing Record 3 of Set 16 | straumen
# Processing Record 4 of Set 16 | mrirt
# City not found. Skipping...
# Processing Record 5 of Set 16 | akdepe
# Processing Record 6 of Set 16 | kapit
# Processing Record 7 of Set 16 | abu samrah
# Processing Record 8 of Set 16 | bijar
# Processing Record 9 of Set 16 | ferme-neuve
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Grand Forks  47.9417  -97.4337     82.78        57          20
# 1        Svetlaya  46.5389  138.3297     63.70        93         100
# 2           Basco  20.4487  121.9702     83.77        75           7
# 3  Ribeira Grande  38.5167  -28.7000     70.20        64          40
# 4           Paris  48.8534    2.3488     77.07        51           0
# 5   Leningradskiy  69.3833  178.4167     37.62        87         100
# 6          Atuona  -9.8000 -139.0333     77.38        78          63
# 7          Avarua -21.2078 -159.7750     75.25        53          75
# 8          Kibala   9.1104   18.3463     80.55        69          20
# 9      Butaritari   3.0707  172.7902     82.13        78          17
#
#    Wind Speed Country                 Date Current Description
# 0        3.44      US  2022-07-10 19:55:49          few clouds
# 1        8.23      RU  2022-07-10 19:55:49     overcast clouds
# 2       11.83      PH  2022-07-10 19:55:49           clear sky
# 3        6.91      PT  2022-07-10 19:54:00    scattered clouds
# 4       12.66      FR  2022-07-10 19:54:00           clear sky
# 5       13.60      RU  2022-07-10 19:55:50     overcast clouds
# 6       17.67      PF  2022-07-10 19:55:50       broken clouds
# 7        5.75      CK  2022-07-10 19:55:50       broken clouds
# 8        3.44      TD  2022-07-10 19:55:50          few clouds
# 9       17.36      KI  2022-07-10 19:54:08          light rain

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Grand Forks      US  47.9417  -97.4337     82.78        57          20
# 1        Svetlaya      RU  46.5389  138.3297     63.70        93         100
# 2           Basco      PH  20.4487  121.9702     83.77        75           7
# 3  Ribeira Grande      PT  38.5167  -28.7000     70.20        64          40
# 4           Paris      FR  48.8534    2.3488     77.07        51           0
# 5   Leningradskiy      RU  69.3833  178.4167     37.62        87         100
# 6          Atuona      PF  -9.8000 -139.0333     77.38        78          63
# 7          Avarua      CK -21.2078 -159.7750     75.25        53          75
# 8          Kibala      TD   9.1104   18.3463     80.55        69          20
# 9      Butaritari      KI   3.0707  172.7902     82.13        78          17
#
#    Wind Speed Current Description
# 0        3.44          few clouds
# 1        8.23     overcast clouds
# 2       11.83           clear sky
# 3        6.91    scattered clouds
# 4       12.66           clear sky
# 5       13.60     overcast clouds
# 6       17.67       broken clouds
# 7        5.75       broken clouds
# 8        3.44          few clouds
# 9       17.36          light rain

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
